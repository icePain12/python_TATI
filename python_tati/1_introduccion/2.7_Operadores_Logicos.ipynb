# %% [markdown]
# # <font color="00AAA">**2.6 Operadores** </font>
# ## **Los operadores aritméticos sirven principalmente para los tipos de datos numéricos, sin embargo tambien pueden ser utilizados con otros tipos de datos como listas o cadenas de caracteres.**

# %% [markdown]
# # <font color="00AAA"> **A) Adición**</font>
# ## *También para cadenas de caracteres, tuplas y listas se seguirá el formato (a + b)

# %%
8 + 30.5
# Out:
# 38.5

# %%
print(0 + True)
# Out:
# 1

# %%
"Hola" +", ¿Cómo estás?"
# Out:
# 'Hola, ¿Cómo estás?'

# %%
print(str(2) + str(2))
# Out:
# 22

# %% [markdown]
# # <font color="00AAA">**Sustracción**</font>

# %%
49 - 30
# Out:
# 19

# %% [markdown]
# # <font color="00AAA"> **C) Multiplicación** </font>
# ## También para cadenas de caracteres, tuplas y listas se deberá seguir el formato (a * b)

# %%
30 * 6
# Out:
# 180

# %%
"TuruTuru" * 2
# Out:
# 'TuruTuruTuruTuru'

# %%
print("Debo hacer la tarea. \n" * 1000)
# Out:
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# Debo hacer la tarea.
# ...

# %% [markdown]
# # <font color="00AAA"> **D) División </font>
# ## *Sigue el formato (a / b)

# %%
10 / 5
# Out:
# 2.0

# %% [markdown]
# # <font color="00AAA"> **E) División Entera Truncada.</font>
# ## *Nos da como resultado un valor de tipo entero. trunca (redondea hacia abajo) los valores decimales siguen el formato (a // b)

# %%
10 // 5
# Out:
# 2

# %% [markdown]
# # <font color="00AAA">**F) Modulo o Residuo de la División</font>
# ## Seguirá el formato (a % b)

# %%
print(5%2)
# Out:
# 1

# %% [markdown]
# # <font color="00AAA">**Seguira el formato(a**b)**

# %% [markdown]
# # <font color="00AAA">**Operadores de Asignacion (Acumuladores)**</font>
# ## Los operadores de asignacion nos facilitan escribir código. Estos son los siguientes:
#
# <ul>
# <li>=</li>
# <li>-=</li>
# <li>+=</li>
# <li>/=</li>
# <li>*=</li>
# <li>%=</li>
# <li>//=</li>
# <li>**=</li>
# </ul>

# %%
edad=10;
print(edad)
# Out:
# 10

# %%
edad = 10
edad -=3
print(edad)
# Out:
# 7

# %%
edad = 10
edad /=5
print(edad)
# Out:
# 2.0

# %%
a = ord('A'),ord('M'),ord('O'),ord('R')
print(a)
b = ord('A'),ord('m'),ord('o'),ord('r')
print(b);
c = ord('a'),ord('m'),ord('o'),ord('r')
print(c)
# Out:
# (65, 77, 79, 82)
# (65, 109, 111, 114)
# (97, 109, 111, 114)

# %%
a = ord('A') + ord('B')
print(a)
print(chr(131))
# Out:
# 131
# 

# %%
print(chr(ord('A')+ord('L')))
# Out:
# 
