# %% [markdown]
# # <font color="00AAA">**Booleanos** </font>
#
# ## **Un Booleano es el tipo de dato lógico. Solo tiene 2 valores: Verdadero o Falso.

# %%
1+1
# Out:
# 2

# %%
1+1==2
# Out:
# True

# %%
1 + 1 == 3
# Out:
# False

# %%
variable = True;
variable
# Out:
# True

# %%
vari = False;
vari
# Out:
# False

# %%
2 == variable
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True
# Out:
# True

# %%
(2== 1+1) and (3==1+2)
# Out:
# True

# %%
(2 == 1+1) and (3 == 1+2)
# Out:
# True

# %%
(5 == 1 + 1) and (4== 1 + 2)
# Out:
# False

# %%
type(variable)
# Out:
# bool
